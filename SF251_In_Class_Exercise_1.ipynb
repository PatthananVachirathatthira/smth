# %% [markdown]
# <a href="https://colab.research.google.com/github/PatthananVachirathatthira/smth/blob/main/SF251_In_Class_Exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In-Class Exercise 1
#
# Once done, upload to MS Teams

# %% [markdown]
# ## Pokemon Dataset Part 1
#
# Data from https://www.kaggle.com/datasets/cristobalmitchell/pokedex
#
# - First, let's explore the data!
# - Click the link above and read through everything.
# - The data is also on the class's github.

# %%
# !wget https://raw.githubusercontent.com/yongsa-nut/SF251_67_2/refs/heads/main/data/pokemon.csv
# Out:
# --2025-01-31 07:18:11--  https://raw.githubusercontent.com/yongsa-nut/SF251_67_2/refs/heads/main/data/pokemon.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 331632 (324K) [text/plain]
# Saving to: ‘pokemon.csv’
#
# pokemon.csv         100%[===================>] 323.86K  --.-KB/s    in 0.02s
#
# 2025-01-31 07:18:11 (19.7 MB/s) - ‘pokemon.csv’ saved [331632/331632]

# %%
import pandas as pd

# %% [markdown]
# **Q1**: Load the data

# %%
pokemon = pd.read_csv('pokemon.csv')

# %% [markdown]
# **Q2**: Check the data using `head()`

# %%
pokemon.head()
# Out:
#    national_number gen english_name japanese_name primary_type secondary_type  \
# 0                1   I    Bulbasaur   Fushigidane        grass         poison
# 1                2   I      Ivysaur    Fushigisou        grass         poison
# 2                3   I     Venusaur   Fushigibana        grass         poison
# 3                4   I   Charmander      Hitokage         fire            NaN
# 4                5   I   Charmeleon       Lizardo         fire            NaN
#
#    classification percent_male percent_female  height_m  ...  evochain_1  \
# 0    Seed Pokémon        88.14          11.86       0.7  ...      Level
# 1    Seed Pokémon        88.14          11.86       1.0  ...      Level
# 2    Seed Pokémon        88.14          11.86       2.0  ...      Level
# 3  Lizard Pokémon        88.14          11.86       0.6  ...      Level
# 4   Flame Pokémon        88.14          11.86       1.1  ...      Level
#
# ...

# %% [markdown]
# **Q3**: How many Pokemon are there in the dataset?

# %%
pokemon.shape
# Out:
# (898, 55)

# %% [markdown]
# **Q4**: List all column names in the dataset

# %%
pokemon.columns
# Out:
# Index(['national_number', 'gen', 'english_name', 'japanese_name',
#        'primary_type', 'secondary_type', 'classification', 'percent_male',
#        'percent_female', 'height_m', 'weight_kg', 'capture_rate',
#        'base_egg_steps', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense',
#        'speed', 'abilities_0', 'abilities_1', 'abilities_2',
#        'abilities_hidden', 'against_normal', 'against_fire', 'against_water',
#        'against_electric', 'against_grass', 'against_ice', 'against_fighting',
#        'against_poison', 'against_ground', 'against_flying', 'against_psychic',
#        'against_bug', 'against_rock', 'against_ghost', 'against_dragon',
#        'against_dark', 'against_steel', 'against_fairy', 'is_sublegendary',
#        'is_legendary', 'is_mythical', 'evochain_0', 'evochain_1', 'evochain_2',
#        'evochain_3', 'evochain_4', 'evochain_5', 'evochain_6', 'gigantamax',
#        'mega_evolution', 'mega_evolution_alt', 'description'],
# ...

# %% [markdown]
# **Q5**: Rename the `national_number` column to `id_number`. Then print the column name.

# %%
pokemon = pokemon.rename(columns={"national_number":"id_number"})
pokemon.columns
# Out:
# Index(['id_number', 'gen', 'english_name', 'japanese_name', 'primary_type',
#        'secondary_type', 'classification', 'percent_male', 'percent_female',
#        'height_m', 'weight_kg', 'capture_rate', 'base_egg_steps', 'hp',
#        'attack', 'defense', 'sp_attack', 'sp_defense', 'speed', 'abilities_0',
#        'abilities_1', 'abilities_2', 'abilities_hidden', 'against_normal',
#        'against_fire', 'against_water', 'against_electric', 'against_grass',
#        'against_ice', 'against_fighting', 'against_poison', 'against_ground',
#        'against_flying', 'against_psychic', 'against_bug', 'against_rock',
#        'against_ghost', 'against_dragon', 'against_dark', 'against_steel',
#        'against_fairy', 'is_sublegendary', 'is_legendary', 'is_mythical',
#        'evochain_0', 'evochain_1', 'evochain_2', 'evochain_3', 'evochain_4',
#        'evochain_5', 'evochain_6', 'gigantamax', 'mega_evolution',
#        'mega_evolution_alt', 'description'],
#       dtype='object')

# %% [markdown]
# **Q6**: Print out all rows of the column `english_name` using `loc`, `iloc` and `[]`

# %%
pokemon.loc[:,['english_name']]
# Out:
#     english_name
# 0      Bulbasaur
# 1        Ivysaur
# 2       Venusaur
# 3     Charmander
# 4     Charmeleon
# ..           ...
# 893    Regieleki
# 894    Regidrago
# 895    Glastrier
# 896    Spectrier
# 897      Calyrex
#
# [898 rows x 1 columns]
# No charts were generated by quickchart

# %%
pokemon.iloc[:,[2]]
# Out:
#     english_name
# 0      Bulbasaur
# 1        Ivysaur
# 2       Venusaur
# 3     Charmander
# 4     Charmeleon
# ..           ...
# 893    Regieleki
# 894    Regidrago
# 895    Glastrier
# 896    Spectrier
# 897      Calyrex
#
# [898 rows x 1 columns]

# %%
pokemon[['english_name']]
# Out:
#     english_name
# 0      Bulbasaur
# 1        Ivysaur
# 2       Venusaur
# 3     Charmander
# 4     Charmeleon
# ..           ...
# 893    Regieleki
# 894    Regidrago
# 895    Glastrier
# 896    Spectrier
# 897      Calyrex
#
# [898 rows x 1 columns]

# %% [markdown]
# **Q7**: List all unique Pokemon types in `primary_type`

# %%
pokemon['primary_type'].unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %% [markdown]
# **Q8**: How many Pokemon are there of each primary type?

# %%
pokemon['primary_type'].value_counts()
# Out:
# primary_type
# water       123
# normal      109
# grass        86
# bug          75
# fire         58
# psychic      58
# rock         50
# electric     49
# dark         36
# fighting     36
# ground       35
# poison       35
# ghost        31
# dragon       31
# steel        30
# ice          28
# fairy        21
# flying        7
# Name: count, dtype: int64

# %% [markdown]
# **Q9**: Print the english name of all Legendary Pokemon that have attack greater than 100
# - Extra: print both english name and attack.

# %%
pokemon[(pokemon['is_legendary']==1) & (pokemon['attack']>100)][['english_name', 'attack']]
# Out:
#     english_name  attack
# 149       Mewtwo     110
# 249        Ho-Oh     130
# 382      Groudon     150
# 383     Rayquaza     150
# 482       Dialga     120
# 483       Palkia     120
# 642     Reshiram     120
# 643       Zekrom     150
# 645       Kyurem     130
# 715      Xerneas     131
# 716      Yveltal     131
# 790     Solgaleo     137
# 791       Lunala     113
# 799     Necrozma     107

# %% [markdown]
# **Q10**: What is the average Attack and Defense for each Pokemon primary type?
# - Hint: Use `group_by`

# %%
pokemon[['primary_type', 'attack', 'defense']].groupby('primary_type').agg("mean")
# Out:
#                  attack     defense
# primary_type
# bug           66.253333   69.346667
# dark          84.361111   66.305556
# dragon        98.806452   76.903226
# electric      73.897959   61.612245
# fairy         63.238095   68.428571
# fighting      99.944444   70.305556
# fire          83.741379   65.051724
# flying        71.571429   62.142857
# ghost         69.483871   76.032258
# grass         72.767442   70.616279
# ground        92.657143   85.142857
# ice           73.071429   73.714286
# normal        73.862385   59.403670
# poison        73.028571   70.742857
# psychic       63.534483   67.948276
# rock          87.120000   98.960000
# steel         88.566667  112.533333
# water         71.195122   70.707317
